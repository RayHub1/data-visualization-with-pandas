# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('medical_examination.csv')

# %%
df.head()
# Out:
#    id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393    2     168    62.0    110     80            1     1      0
# 1   1  20228    1     156    85.0    140     90            3     1      0
# 2   2  18857    1     165    64.0    130     70            3     1      0
# 3   3  17623    2     169    82.0    150    100            1     1      0
# 4   4  17474    1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
# Calculate BMI and determine overweight
df['bmi'] = df['weight'] / ((df['height'] *0.01)**2)

# %%
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            1     1
# 1          1  20228    1     156    85.0    140     90            3     1
# 2          2  18857    1     165    64.0    130     70            3     1
# 3          3  17623    2     169    82.0    150    100            1     1
# 4          4  17474    1     156    56.0    100     60            1     1
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            1     1
# 69996  99995  22601    1     158   126.0    140     90            2     2
# 69997  99996  19066    2     183   105.0    180     90            3     1
# 69998  99998  22431    1     163    72.0    135     80            1     2
# 69999  99999  20540    1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio        bmi
# ...

# %%
df['overweight'] = (df['bmi'] > 25).astype(int)
#we create the "overweight" column based on whether the BMI is greater than 25, converting the boolean result to integers (1 for True and 0 for False).

# %%
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            1     1
# 1          1  20228    1     156    85.0    140     90            3     1
# 2          2  18857    1     165    64.0    130     70            3     1
# 3          3  17623    2     169    82.0    150    100            1     1
# 4          4  17474    1     156    56.0    100     60            1     1
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            1     1
# 69996  99995  22601    1     158   126.0    140     90            2     2
# 69997  99996  19066    2     183   105.0    180     90            3     1
# 69998  99998  22431    1     163    72.0    135     80            1     2
# 69999  99999  20540    1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio        bmi  overweight
# ...

# %% [markdown]
# Normalize the data by making 0 always good and 1 always bad. If the value of cholesterol or gluc is 1, make the value 0. If the value is more than 1, make the value 1.

# %%
# Normalize cholesterol and gluc columns
df['cholesterol'] = df['cholesterol'].apply(lambda x: 0 if x == 1 else 1)
df['gluc'] = df['gluc'].apply(lambda x: 0 if x == 1 else 1)

# %%
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            0     0
# 1          1  20228    1     156    85.0    140     90            1     0
# 2          2  18857    1     165    64.0    130     70            1     0
# 3          3  17623    2     169    82.0    150    100            0     0
# 4          4  17474    1     156    56.0    100     60            0     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            0     0
# 69996  99995  22601    1     158   126.0    140     90            1     1
# 69997  99996  19066    2     183   105.0    180     90            1     0
# 69998  99998  22431    1     163    72.0    135     80            0     1
# 69999  99999  20540    1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio        bmi  overweight
# ...

# %%
# Convert data to long format
df_long = pd.melt(df, id_vars=['cardio'], value_vars= ['cholesterol', 'gluc', 'smoke', 'alco', 'active','overweight'], value_name='Value')

# %%
df_long
# Out:
#         cardio     variable  Value
# 0            0  cholesterol      0
# 1            1  cholesterol      1
# 2            1  cholesterol      1
# 3            1  cholesterol      0
# 4            0  cholesterol      0
# ...        ...          ...    ...
# 419995       0   overweight      1
# 419996       1   overweight      1
# 419997       1   overweight      1
# 419998       1   overweight      1
# 419999       0   overweight      0
#
# [420000 rows x 3 columns]

# %%
# Create the chart using Seaborn's catplot
g = sns.catplot(
    data=df_long, 
    kind='count', 
    x='variable', 
    hue='Value', 
    col='cardio', 
    height=4, 
    aspect=2.0,
    palette='Set1',  # You can specify a custom color palette here
)
# Set plot labels and titles
g.set_axis_labels('variables', 'Count')
g.set_titles('cardio = {col_name}') 
# Show the plot
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# Clean the data. Filter out the following patient segments that represent incorrect data:
# diastolic pressure is higher than systolic (Keep the correct data with (df['ap_lo'] <= df['ap_hi']))

# %%
 df_cleaned = df[df['ap_lo'] <= df['ap_hi']]

# %%
 df_cleaned
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            0     0
# 1          1  20228    1     156    85.0    140     90            1     0
# 2          2  18857    1     165    64.0    130     70            1     0
# 3          3  17623    2     169    82.0    150    100            0     0
# 4          4  17474    1     156    56.0    100     60            0     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            0     0
# 69996  99995  22601    1     158   126.0    140     90            1     1
# 69997  99996  19066    2     183   105.0    180     90            1     0
# 69998  99998  22431    1     163    72.0    135     80            0     1
# 69999  99999  20540    1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio        bmi  overweight
# ...

# %% [markdown]
# height is less than the 2.5th percentile (Keep the correct data with (df['height'] >= df['height'].quantile(0.025)))

# %%
df_cleaned = df[(df['height'] >= df['height'].quantile(0.025)) & (df['ap_lo'] <= df['ap_hi'])]

# %%
df_cleaned
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            0     0
# 1          1  20228    1     156    85.0    140     90            1     0
# 2          2  18857    1     165    64.0    130     70            1     0
# 3          3  17623    2     169    82.0    150    100            0     0
# 4          4  17474    1     156    56.0    100     60            0     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            0     0
# 69996  99995  22601    1     158   126.0    140     90            1     1
# 69997  99996  19066    2     183   105.0    180     90            1     0
# 69998  99998  22431    1     163    72.0    135     80            0     1
# 69999  99999  20540    1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio        bmi  overweight
# ...

# %% [markdown]
# height is more than the 97.5th percentile

# %%
# Filter out data where height is greater than the 97.5th percentile
df_cleaned = df[df['height'] <= df['height'].quantile(0.975)]

# %%
df_cleaned
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            0     0
# 1          1  20228    1     156    85.0    140     90            1     0
# 2          2  18857    1     165    64.0    130     70            1     0
# 3          3  17623    2     169    82.0    150    100            0     0
# 4          4  17474    1     156    56.0    100     60            0     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69994  99992  21074    1     165    80.0    150     80            0     0
# 69995  99993  19240    2     168    76.0    120     80            0     0
# 69996  99995  22601    1     158   126.0    140     90            1     1
# 69998  99998  22431    1     163    72.0    135     80            0     1
# 69999  99999  20540    1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio        bmi  overweight
# ...

# %% [markdown]
# weight is less than the 2.5th percentile

# %%
# Filter out data where weight is less than the 2.5th percentile
df_cleaned = df[df['weight'] >= df['weight'].quantile(0.025)]

# %%
df_cleaned
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            0     0
# 1          1  20228    1     156    85.0    140     90            1     0
# 2          2  18857    1     165    64.0    130     70            1     0
# 3          3  17623    2     169    82.0    150    100            0     0
# 4          4  17474    1     156    56.0    100     60            0     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            0     0
# 69996  99995  22601    1     158   126.0    140     90            1     1
# 69997  99996  19066    2     183   105.0    180     90            1     0
# 69998  99998  22431    1     163    72.0    135     80            0     1
# 69999  99999  20540    1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio        bmi  overweight
# ...

# %% [markdown]
# weight is more than the 97.5th percentile

# %%
# Filter out data where weight is more than the 97.5th percentile
df_cleaned = df[df['weight'] <= df['weight'].quantile(0.975)]

# %%
df_cleaned
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            0     0
# 1          1  20228    1     156    85.0    140     90            1     0
# 2          2  18857    1     165    64.0    130     70            1     0
# 3          3  17623    2     169    82.0    150    100            0     0
# 4          4  17474    1     156    56.0    100     60            0     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69994  99992  21074    1     165    80.0    150     80            0     0
# 69995  99993  19240    2     168    76.0    120     80            0     0
# 69997  99996  19066    2     183   105.0    180     90            1     0
# 69998  99998  22431    1     163    72.0    135     80            0     1
# 69999  99999  20540    1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio        bmi  overweight
# ...

# %% [markdown]
# Create a correlation matrix using the dataset. Plot the correlation matrix using seaborn's heatmap(). Mask the upper triangle. The chart should look like examples/Figure_2.png.

# %%
# Calculate the correlation matrix
corr_matrix = df.corr()

# %%
corr_matrix
# Out:
#                    id       age       sex    height    weight     ap_hi  \
# id           1.000000  0.003457  0.003154 -0.003038 -0.001830  0.003356
# age          0.003457  1.000000 -0.022609 -0.081515  0.053684  0.020764
# sex          0.003154 -0.022609  1.000000  0.498221  0.155115  0.005985
# height      -0.003038 -0.081515  0.498221  1.000000  0.290968  0.005488
# weight      -0.001830  0.053684  0.155115  0.290968  1.000000  0.030702
# ap_hi        0.003356  0.020764  0.005985  0.005488  0.030702  1.000000
# ap_lo       -0.002529  0.017647  0.015195  0.006150  0.043710  0.016086
# cholesterol  0.005290  0.129697 -0.034729 -0.048532  0.137981  0.024730
# gluc         0.002844  0.088099 -0.018318 -0.019400  0.120407  0.012886
# smoke       -0.003699 -0.047633  0.337664  0.187989  0.067780 -0.000922
# alco         0.001210 -0.029723  0.170682  0.094419  0.067113  0.001408
# active       0.003755 -0.009927  0.005991 -0.006570 -0.016867 -0.000033
# ...

# %%
# Create a mask to hide the upper triangle
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

# %%
mask
# Out:
# array([[ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True],
#        [False,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True],
#        [False, False,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True],
#        [False, False, False,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True],
#        [False, False, False, False,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True],
#        [False, False, False, False, False,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True],
#        [False, False, False, False, False, False,  True,  True,  True,
#          True,  True,  True,  True,  True,  True],
#        [False, False, False, False, False, False, False,  True,  True,
# ...

# %%
# Set up the matplotlib figure
plt.figure(figsize=(10, 8))

# Create a heatmap with Seaborn
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5, mask=mask)

# Customize the plot
plt.title("Correlation Matrix")
plt.xticks(rotation=45)

# Show the plot
plt.show()
