# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_excel('data\\patientline list.xlsx')

# %%
df
# Out:
#           State   LGA                   Facility Name     Datim Id  \
# 0     Akwa Ibom  Oron  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# 1     Akwa Ibom  Oron  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# 2     Akwa Ibom  Oron  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# 3     Akwa Ibom  Oron  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# 4     Akwa Ibom  Oron  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# ...         ...   ...                             ...          ...
# 3884  Akwa Ibom  Oron  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# 3885  Akwa Ibom  Oron  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# 3886  Akwa Ibom  Oron  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# 3887  Akwa Ibom  Oron  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# 3888  Akwa Ibom  Oron  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
#
#                                 Patient Id                       id  \
# 0     00003d1a-94b5-4811-848d-57d8df2dd39f  HAN/AKS/EYF/TG2/B10/509
# ...

# %%
df.shape
# Out:
# (3889, 58)

# %%
art_start = df['Current Status']

# %%
art_start
# Out:
# 0                 ACTIVE
# 1       ART_TRANSFER_OUT
# 2                 ACTIVE
# 3                 ACTIVE
# 4                 ACTIVE
#               ...
# 3884    ART Transfer Out
# 3885              ACTIVE
# 3886              ACTIVE
# 3887              ACTIVE
# 3888              ACTIVE
# Name: Current Status, Length: 3889, dtype: object

# %%
active = df[art_start  == 'ACTIVE']

# %%
active.shape
# Out:
# (3561, 58)

# %%
active.shape[0]
# Out:
# 3561

# %%
active
# Out:
#           State   LGA                   Facility Name     Datim Id  \
# 0     Akwa Ibom  Oron  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# 2     Akwa Ibom  Oron  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# 3     Akwa Ibom  Oron  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# 4     Akwa Ibom  Oron  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# 5     Akwa Ibom  Oron  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# ...         ...   ...                             ...          ...
# 3883  Akwa Ibom  Oron  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# 3885  Akwa Ibom  Oron  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# 3886  Akwa Ibom  Oron  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# 3887  Akwa Ibom  Oron  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# 3888  Akwa Ibom  Oron  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
#
#                                 Patient Id                       id  \
# 0     00003d1a-94b5-4811-848d-57d8df2dd39f  HAN/AKS/EYF/TG2/B10/509
# ...

# %%
df1 = pd.read_excel('data\\radet1.xlsx', usecols=['id', 'Target group',])

# %%
df1
# Out:
#                            id Target group
# 0     HAN/AKS/EYF/TG2/B10/509          FSW
# 1      HAI/AKS/EYF/TG2/9C/012          FSW
# 2      HAI/AKS/ENW/TG2/B7/396          FSW
# 3      HAN/AKS/RNN/TG2/B7/651          FSW
# 4     HAN/AKS/RNN/SP2/B14/879           SP
# ...                       ...          ...
# 3884   HAN/AKS/EYF/TG2/B7/401          FSW
# 3885   HAI/AKS/ENW/TG1/B7/372          MSM
# 3886  HAN/AKS/KPD/SP2/B14/411           SP
# 3887   HAI/AKS/ENW/TG2/A7/143          FSW
# 3888   HAN/AKS/RNN/TG2/B5/665          FSW
#
# [3889 rows x 2 columns]

# %%
merged_df = df1.merge(df, on='id', how='left')

# %%
merged_df
# Out:
#                            id Target group      State   LGA  \
# 0     HAN/AKS/EYF/TG2/B10/509          FSW  Akwa Ibom  Oron
# 1      HAI/AKS/EYF/TG2/9C/012          FSW  Akwa Ibom  Oron
# 2      HAI/AKS/ENW/TG2/B7/396          FSW  Akwa Ibom  Oron
# 3      HAN/AKS/RNN/TG2/B7/651          FSW  Akwa Ibom  Oron
# 4     HAN/AKS/RNN/SP2/B14/879           SP  Akwa Ibom  Oron
# ...                       ...          ...        ...   ...
# 3884   HAN/AKS/EYF/TG2/B7/401          FSW  Akwa Ibom  Oron
# 3885   HAI/AKS/ENW/TG1/B7/372          MSM  Akwa Ibom  Oron
# 3886  HAN/AKS/KPD/SP2/B14/411           SP  Akwa Ibom  Oron
# 3887   HAI/AKS/ENW/TG2/A7/143          FSW  Akwa Ibom  Oron
# 3888   HAN/AKS/RNN/TG2/B5/665          FSW  Akwa Ibom  Oron
#
#                        Facility Name     Datim Id  \
# 0     Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# 1     Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# 2     Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# ...

# %%
merged_df.shape[1]
# Out:
# 59

# %%
merged_df.to_excel('merged_df.xlsx', index=None)

# %%
merged_df.head(1)
# Out:
#                         id Target group      State   LGA  \
# 0  HAN/AKS/EYF/TG2/B10/509          FSW  Akwa Ibom  Oron
#
#                     Facility Name     Datim Id  \
# 0  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
#
#                              Patient Id           Unique ID Surname  \
# 0  00003d1a-94b5-4811-848d-57d8df2dd39f  HALG/3/4/65/003442    Edem
#
#     Other Name  ... DMOC Type  Date Devolved (yyyy-mm-dd) Last Clinic Stage  \
# 0  Angela Etim  ...       NaN                         NaN           STAGE I
#
#   Date of Last Clinic (yyyy-mm-dd) Date of Next Clinic (yyyy-mm-dd)  \
# 0                       2023-07-13                       2024-01-04
#
#   Date of Sample Collection  Last Viral Load  \
# 0                2023-07-20              0.0
#
#    Date of Last Viral Load (yyyy-mm-dd)      Viral Load Indication  \
# 0                            2023-09-05  Routine (every 12 months)
#
#   Case-manager
# 0          NaN
#
# [1 rows x 59 columns]

# %%
new_status = merged_df['Current Status']

# %%
new_active = merged_df[new_status == 'ACTIVE']

# %%
new_active.shape[0]
# Out:
# 3561

# %%
new_active
# Out:
#                            id Target group      State   LGA  \
# 0     HAN/AKS/EYF/TG2/B10/509          FSW  Akwa Ibom  Oron
# 2      HAI/AKS/ENW/TG2/B7/396          FSW  Akwa Ibom  Oron
# 3      HAN/AKS/RNN/TG2/B7/651          FSW  Akwa Ibom  Oron
# 4     HAN/AKS/RNN/SP2/B14/879           SP  Akwa Ibom  Oron
# 5     HAN/AKS/ENW/TG1/B10/801          MSM  Akwa Ibom  Oron
# ...                       ...          ...        ...   ...
# 3883   HAI/AKS/RNN/TG2/9C/059          FSW  Akwa Ibom  Oron
# 3885   HAI/AKS/ENW/TG1/B7/372          MSM  Akwa Ibom  Oron
# 3886  HAN/AKS/KPD/SP2/B14/411           SP  Akwa Ibom  Oron
# 3887   HAI/AKS/ENW/TG2/A7/143          FSW  Akwa Ibom  Oron
# 3888   HAN/AKS/RNN/TG2/B5/665          FSW  Akwa Ibom  Oron
#
#                        Facility Name     Datim Id  \
# 0     Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# 2     Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# 3     Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# ...

# %%
tg = new_active['Target group']

# %%
tg
# Out:
# 0       FSW
# 2       FSW
# 3       FSW
# 4        SP
# 5       MSM
#        ...
# 3883    FSW
# 3885    MSM
# 3886     SP
# 3887    FSW
# 3888    FSW
# Name: Target group, Length: 3561, dtype: object

# %%
pediatrics = new_active [tg == 'PED']

# %%
pediatrics
# Out:
#                        id Target group      State   LGA  \
# 373   HAN/AKS/KPD/PED/001          PED  Akwa Ibom  Oron
# 918   HAN/AKS/EYF/PED/003          PED  Akwa Ibom  Oron
# 1123  HAN/AKS/RNN/PED/005          PED  Akwa Ibom  Oron
# 1392  HAN/AKS/RNN/PED/004          PED  Akwa Ibom  Oron
# 1413  HAN/AKS/RNN/PED/006          PED  Akwa Ibom  Oron
# 1727  HAN/AKS/EYF/PED/001          PED  Akwa Ibom  Oron
# 3183  HAN/AKS/KPD/PED/003          PED  Akwa Ibom  Oron
# 3216  HAN/AKS/ENW/PED/002          PED  Akwa Ibom  Oron
# 3483  HAN/AKS/EYF/PED/002          PED  Akwa Ibom  Oron
# 3486  HAN/AKS/UFG/PED/001          PED  Akwa Ibom  Oron
# 3799  HAN/AKS/KPD/PED/002          PED  Akwa Ibom  Oron
# 3810  HAN/AKS/ENW/PED/004          PED  Akwa Ibom  Oron
#
#                        Facility Name     Datim Id  \
# 373   Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# 918   Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# 1123  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# ...

# %%
pediatrics.shape[0]
# Out:
# 12

# %%
missing_weight = new_active[new_active['Baseline Weight (kg)'].isna()]

# %%
missing_weight
# Out:
# Empty DataFrame
# ...

# %%
missing_height = new_active[new_active['Baseline Height (cm)'].isnull()]

# %%
missing_height
# Out:
#                            id Target group      State   LGA  \
# 2      HAI/AKS/ENW/TG2/B7/396          FSW  Akwa Ibom  Oron
# 5     HAN/AKS/ENW/TG1/B10/801          MSM  Akwa Ibom  Oron
# 6     HAN/AKS/ENW/TG3/B7/1020         PWID  Akwa Ibom  Oron
# 7     HAN/AKS/KPD/TG2/B10/218          FSW  Akwa Ibom  Oron
# 12     HAI/AKS/ENW/TG1/B7/354          MSM  Akwa Ibom  Oron
# ...                       ...          ...        ...   ...
# 3877   HAI/AKS/EYF/TG2/B7/258          FSW  Akwa Ibom  Oron
# 3880  HAI/AKS/ENW/SP1/B14/625           SP  Akwa Ibom  Oron
# 3882   HAI/AKS/ENW/TG1/B7/327          MSM  Akwa Ibom  Oron
# 3885   HAI/AKS/ENW/TG1/B7/372          MSM  Akwa Ibom  Oron
# 3887   HAI/AKS/ENW/TG2/A7/143          FSW  Akwa Ibom  Oron
#
#                        Facility Name     Datim Id  \
# 2     Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# 5     Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# 6     Oron KP One Stop Shop- Virtual  xtcq7SetHe8
# ...

# %%
 missing_height.shape[0]
# Out:
# 1505

# %%
 mean_height = new_active['Baseline Height (cm)'].mean()

# %%
 mean_height
# Out:
# 159.31746108949417

# %%
mean_height_rounded = round(mean_height, 1)

# %%
mean_height_rounded
# Out:
# 159.3

# %%
new_active['Baseline Height (cm)'].fillna(mean_height_rounded, inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7652\724057159.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_active['Baseline Height (cm)'].fillna(mean_height_rounded, inplace=True)

# %%
new_missing_height = new_active[new_active['Baseline Height (cm)'].isnull()]

# %%
new_missing_height
# Out:
# Empty DataFrame
# ...

# %%
value_at_12th_row = new_active.loc[12, 'Baseline Height (cm)']

# %%
value_at_12th_row
# Out:
# 159.3

# %%
wrong_stage = new_active[new_active['Baseline Clinic Stage'] != 'STAGE I']

# %%
wrong_stage
# Out:
# Empty DataFrame
# ...

# %%
wrong_fuctional_status = new_active[new_active['Baseline Functional Status'] != 'Working']

# %%
wrong_fuctional_status
# Out:
# Empty DataFrame
# ...

# %%
wrong_current_weight = new_active[new_active['Current Weight (kg)'].isna()]

# %%
wrong_current_weight
# Out:
#                            id Target group      State   LGA  \
# 2992  HAN/AKS/EYF/TG2/B11/381          FSW  Akwa Ibom  Oron
#
#                        Facility Name     Datim Id  \
# 2992  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
#
#                                 Patient Id           Unique ID Surname  \
# 2992  c60b7b42-5050-4757-b879-bec8ab976369  HALG/3/4/65/002008    Edem
#
#          Other Name  ... DMOC Type  Date Devolved (yyyy-mm-dd)  \
# 2992  Inifon Asukwo  ...       NaN                         NaN
#
#      Last Clinic Stage Date of Last Clinic (yyyy-mm-dd)  \
# 2992               NaN                              NaT
#
#      Date of Next Clinic (yyyy-mm-dd) Date of Sample Collection  \
# 2992                              NaT                2023-04-12
#
#       Last Viral Load  Date of Last Viral Load (yyyy-mm-dd)  \
# 2992              0.0                            2023-06-12
#
#           Viral Load Indication Case-manager
# ...

# %%
current_weight_mean = new_active['Current Weight (kg)'].mean()

# %%
current_weight_mean
# Out:
# 63.0845786516854

# %%
current_weight_mean_rounded = round(current_weight_mean, 1)

# %%
current_weight_mean_rounded
# Out:
# 63.1

# %%
new_active['Current Weight (kg)'].fillna(current_weight_mean_rounded, inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7652\1643556009.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_active['Current Weight (kg)'].fillna(current_weight_mean_rounded, inplace=True)

# %%
new_wrong_current_weight = new_active[new_active['Current Weight (kg)'].isna()]

# %%
new_wrong_current_weight
# Out:
# Empty DataFrame
# ...

# %%
null_current_height = new_active[new_active['Current Height (cm)'].isna()]

# %%
null_current_height
# Out:
#                            id Target group      State   LGA  \
# 2992  HAN/AKS/EYF/TG2/B11/381          FSW  Akwa Ibom  Oron
#
#                        Facility Name     Datim Id  \
# 2992  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
#
#                                 Patient Id           Unique ID Surname  \
# 2992  c60b7b42-5050-4757-b879-bec8ab976369  HALG/3/4/65/002008    Edem
#
#          Other Name  ... DMOC Type  Date Devolved (yyyy-mm-dd)  \
# 2992  Inifon Asukwo  ...       NaN                         NaN
#
#      Last Clinic Stage Date of Last Clinic (yyyy-mm-dd)  \
# 2992               NaN                              NaT
#
#      Date of Next Clinic (yyyy-mm-dd) Date of Sample Collection  \
# 2992                              NaT                2023-04-12
#
#       Last Viral Load  Date of Last Viral Load (yyyy-mm-dd)  \
# 2992              0.0                            2023-06-12
#
#           Viral Load Indication Case-manager
# ...

# %%
mean_null_current_height = new_active['Current Height (cm)'].mean()

# %%
mean_null_current_height_round = round(mean_null_current_height, 1)

# %%
mean_null_current_height_round
# Out:
# 160.0

# %%
new_active['Current Height (cm)'].fillna(mean_null_current_height_round, inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7652\1394505365.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_active['Current Height (cm)'].fillna(mean_null_current_height_round, inplace=True)

# %%
new_null_current_height = new_active[new_active['Current Height (cm)'].isna()]

# %%
new_null_current_height
# Out:
# Empty DataFrame
# ...

# %%
current_systolic = new_active[(new_active['Current Systolic BP'].isna()) & (new_active['Target group'] != 'PED')]

# %%
current_systolic
# Out:
#                            id Target group      State   LGA  \
# 2992  HAN/AKS/EYF/TG2/B11/381          FSW  Akwa Ibom  Oron
#
#                        Facility Name     Datim Id  \
# 2992  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
#
#                                 Patient Id           Unique ID Surname  \
# 2992  c60b7b42-5050-4757-b879-bec8ab976369  HALG/3/4/65/002008    Edem
#
#          Other Name  ... DMOC Type  Date Devolved (yyyy-mm-dd)  \
# 2992  Inifon Asukwo  ...       NaN                         NaN
#
#      Last Clinic Stage Date of Last Clinic (yyyy-mm-dd)  \
# 2992               NaN                              NaT
#
#      Date of Next Clinic (yyyy-mm-dd) Date of Sample Collection  \
# 2992                              NaT                2023-04-12
#
#       Last Viral Load  Date of Last Viral Load (yyyy-mm-dd)  \
# 2992              0.0                            2023-06-12
#
#           Viral Load Indication Case-manager
# ...

# %%
mean_null_systolic = new_active['Current Systolic BP'].mean()

# %%
mean_null_systolic
# Out:
# 112.45518602029313

# %%
mean_null_systolic_round = round(mean_null_systolic, 1)

# %%
mean_null_systolic_round
# Out:
# 112.5

# %%
new_active['Current Systolic BP'].fillna(mean_null_systolic_round, inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7652\1816923742.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_active['Current Systolic BP'].fillna(mean_null_systolic_round, inplace=True)

# %%
new_current_systolic = new_active[(new_active['Current Systolic BP'].isna()) & (new_active['Target group'] != 'PED')]

# %%
new_current_systolic
# Out:
# Empty DataFrame
# ...

# %%
current_diastolic = new_active[(new_active['Current Diastolic BP'].isna()) & (new_active['Target group'] != 'PED')]

# %%
current_diastolic
# Out:
#                            id Target group      State   LGA  \
# 2992  HAN/AKS/EYF/TG2/B11/381          FSW  Akwa Ibom  Oron
#
#                        Facility Name     Datim Id  \
# 2992  Oron KP One Stop Shop- Virtual  xtcq7SetHe8
#
#                                 Patient Id           Unique ID Surname  \
# 2992  c60b7b42-5050-4757-b879-bec8ab976369  HALG/3/4/65/002008    Edem
#
#          Other Name  ... DMOC Type  Date Devolved (yyyy-mm-dd)  \
# 2992  Inifon Asukwo  ...       NaN                         NaN
#
#      Last Clinic Stage Date of Last Clinic (yyyy-mm-dd)  \
# 2992               NaN                              NaT
#
#      Date of Next Clinic (yyyy-mm-dd) Date of Sample Collection  \
# 2992                              NaT                2023-04-12
#
#       Last Viral Load  Date of Last Viral Load (yyyy-mm-dd)  \
# 2992              0.0                            2023-06-12
#
#           Viral Load Indication Case-manager
# ...

# %%
mean_null_diastolic = new_active['Current Diastolic BP'].mean()

# %%
mean_null_diastolic
# Out:
# 73.55073280721533

# %%
mean_null_diastolic_round = round(mean_null_diastolic, 1)

# %%
mean_null_diastolic_round
# Out:
# 73.6

# %%
new_active['Current Diastolic BP'].fillna(mean_null_diastolic_round, inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7652\3651387852.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_active['Current Diastolic BP'].fillna(mean_null_diastolic_round, inplace=True)

# %%
new_current_diastolic = current_diastolic = new_active[(new_active['Current Diastolic BP'].isna()) & (new_active['Target group'] != 'PED')]

# %%
new_current_diastolic
# Out:
# Empty DataFrame
# ...

# %%
merged_df.update(new_active)

# %%
merged_df.update(new_active)

# %%
new_patient_line_list = merged_df.drop('Target group', axis=1)

# %%
new_patient_line_list.to_excel('patient line list.xlsx', index=None)
