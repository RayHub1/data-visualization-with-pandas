# %%
import pandas as pd
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re

# %matplotlib inline

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df1 = pd.read_excel('data\\pl.xlsx', usecols=['Hospital Number', 'Surname', 'Other Name'])

# %%
df2 = pd.read_excel('data\\or.xlsx')

# %%
df1
# Out:
#               Hospital Number    Surname        Other Name
# 0     HAN/AKS/EYF/TG2/B10/509       Edem       Angela Etim
# 1      HAI/AKS/EYF/TG2/9C/012       Edet  Abasiakan Joseph
# 2      HAI/AKS/ENW/TG2/B7/396     Bassey        Chiborg. O
# 3      HAN/AKS/RNN/TG2/B7/651       Etim        Nko Asukwo
# 4     HAN/AKS/RNN/SP2/B14/879    Micheal    Kenneth Bassey
# ...                       ...        ...               ...
# 3874   HAN/AKS/EYF/TG2/B7/401     Bassey     Esther Asukwo
# 3875   HAI/AKS/ENW/TG1/B7/372  Ibechukwu          Ndubussi
# 3876  HAN/AKS/KPD/SP2/B14/411       Anso        Isaac Edet
# 3877   HAI/AKS/ENW/TG2/A7/143        Kpe            Eunice
# 3878   HAN/AKS/RNN/TG2/B5/665       Edet      Queen Manson
#
# [3879 rows x 3 columns]

# %%
df2
# Out:
#       S/No.      State L.G.A LGA Of Residence                   Facility Name  \
# 0         1  Akwa Ibom  Oron              NaN  Oron KP One Stop Shop- Virtual
# 1         2  Akwa Ibom  Oron              NaN  Oron KP One Stop Shop- Virtual
# 2         3  Akwa Ibom  Oron              Mbo  Oron KP One Stop Shop- Virtual
# 3         4  Akwa Ibom  Oron             Oron  Oron KP One Stop Shop- Virtual
# 4         5  Akwa Ibom  Oron             Oron  Oron KP One Stop Shop- Virtual
# ...     ...        ...   ...              ...                             ...
# 3873   3874  Akwa Ibom  Oron              NaN  Oron KP One Stop Shop- Virtual
# 3874   3875  Akwa Ibom  Oron              Mbo  Oron KP One Stop Shop- Virtual
# 3875   3876  Akwa Ibom  Oron            Okobo  Oron KP One Stop Shop- Virtual
# 3876   3877  Akwa Ibom  Oron              Mbo  Oron KP One Stop Shop- Virtual
# 3877   3878  Akwa Ibom  Oron             Oron  Oron KP One Stop Shop- Virtual
#
# ...

# %%
merged_df = df2.merge(df1, on='Hospital Number', how='left')

# %%
merged_df.to_excel('data\\utput_file.xlsx', index=False)
